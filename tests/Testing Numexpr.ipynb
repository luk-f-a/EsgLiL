# %%
import sympy as sp

# %%
import numexpr as ne

# %%
import numpy as np

# %% [markdown]
# ## Numpexpr on dag generated from dask

# %%
def cal(input_1): 
    evaluate = ne.evaluate
    input_1_49_1= input_1[0]
    input_1_47_0= input_1[1]
    input_1_43_0= input_1[2]
    input_1_42_0= input_1[3]
    input_1_41_0= input_1[4]
    input_1_31_0= input_1[5]
    input_1_23_0= input_1[6]
    input_1_18_0= input_1[7]
    input_1_16_0= input_1[8]
    input_1_4_0= input_1[9]
    input_1_0_0= input_1[10]
    input_1_1_0= input_1[11]
    input_1_2_0= input_1[12]
    input_1_3_0= input_1[13]
    input_1_5_0= input_1[14]
    input_1_6_0= input_1[15]
    input_1_7_0= input_1[16]
    input_1_8_0= input_1[17]
    input_1_9_0= input_1[18]
    input_1_10_0= input_1[19]
    input_1_11_0= input_1[20]
    input_1_12_0= input_1[21]
    input_1_13_0= input_1[22]
    input_1_14_0= input_1[23]
    input_1_15_0= input_1[24]
    input_1_17_0= input_1[25]
    input_1_19_0= input_1[26]
    input_1_20_0= input_1[27]
    input_1_21_0= input_1[28]
    input_1_22_0= input_1[29]
    input_1_24_0= input_1[30]
    input_1_25_0= input_1[31]
    input_1_26_0= input_1[32]
    input_1_27_0= input_1[33]
    input_1_28_0= input_1[34]
    input_1_29_0= input_1[35]
    input_1_30_0= input_1[36]
    input_1_32_0= input_1[37]
    input_1_33_0= input_1[38]
    input_1_34_0= input_1[39]
    input_1_35_0= input_1[40]
    input_1_36_0= input_1[41]
    input_1_37_0= input_1[42]
    input_1_38_0= input_1[43]
    input_1_39_0= input_1[44]
    input_1_40_0= input_1[45]
    input_1_44_0= input_1[46]
    input_1_45_0= input_1[47]
    input_1_46_0= input_1[48]
    input_1_48_0= input_1[49]
    input_1_49_0= input_1[50]
    input_1_46_1= input_1[51]
    input_1_45_1= input_1[52]
    input_1_43_1= input_1[53]
    input_1_41_1= input_1[54]
    input_1_40_1= input_1[55]
    input_1_39_1= input_1[56]
    input_1_36_1= input_1[57]
    input_1_35_1= input_1[58]
    input_1_32_1= input_1[59]
    input_1_31_1= input_1[60]
    input_1_29_1= input_1[61]
    input_1_25_1= input_1[62]
    input_1_22_1= input_1[63]
    input_1_20_1= input_1[64]
    input_1_19_1= input_1[65]
    input_1_18_1= input_1[66]
    input_1_13_1= input_1[67]
    input_1_11_1= input_1[68]
    input_1_9_1= input_1[69]
    input_1_8_1= input_1[70]
    input_1_7_1= input_1[71]
    input_1_3_1= input_1[72]
    input_1_2_1= input_1[73]
    input_1_1_1= input_1[74]
    input_1_0_1= input_1[75]
    input_1_4_1= input_1[76]
    input_1_5_1= input_1[77]
    input_1_6_1= input_1[78]
    input_1_10_1= input_1[79]
    input_1_12_1= input_1[80]
    input_1_14_1= input_1[81]
    input_1_15_1= input_1[82]
    input_1_16_1= input_1[83]
    input_1_17_1= input_1[84]
    input_1_21_1= input_1[85]
    input_1_23_1= input_1[86]
    input_1_24_1= input_1[87]
    input_1_26_1= input_1[88]
    input_1_27_1= input_1[89]
    input_1_28_1= input_1[90]
    input_1_30_1= input_1[91]
    input_1_33_1= input_1[92]
    input_1_34_1= input_1[93]
    input_1_37_1= input_1[94]
    input_1_38_1= input_1[95]
    input_1_42_1= input_1[96]
    input_1_44_1= input_1[97]
    input_1_47_1= input_1[98]
    input_1_48_1= input_1[99]
    mul0 = evaluate("(0.001* ( (0+ (input_1_0_0*0.01))-0.0))")
    add1 = evaluate("( ( (0+ (input_1_0_0*0.01))-0.0)+ (input_1_1_0*0.01))")
    add2 = evaluate("( (add1- (mul0*0.1))+ (input_1_2_0*0.01))")
    mul3 = evaluate("( (0.001* (add1- (mul0*0.1)))*0.09999999999999998)")
    sub4 = evaluate("( ( (add2-mul3)+ (input_1_3_0*0.01))- ( (0.001* (add2-mul3))*0.10000000000000003))")
    sub5 = evaluate("( (sub4+ (input_1_4_0*0.01))- ( (0.001*sub4)*0.09999999999999998))")
    sub6 = evaluate("( (sub5+ (input_1_5_0*0.01))- ( (0.001*sub5)*0.09999999999999998))")
    sub7 = evaluate("( (sub6+ (input_1_6_0*0.01))- ( (0.001*sub6)*0.09999999999999998))")
    sub8 = evaluate("( (sub7+ (input_1_7_0*0.01))- ( (0.001*sub7)*0.10000000000000009))")
    sub9 = evaluate("( (sub8+ (input_1_8_0*0.01))- ( (0.001*sub8)*0.09999999999999998))")
    sub10 = evaluate("( (sub9+ (input_1_9_0*0.01))- ( (0.001*sub9)*0.09999999999999998))")
    sub11 = evaluate("( (sub10+ (input_1_10_0*0.01))- ( (0.001*sub10)*0.10000000000000009))")
    sub12 = evaluate("( (sub11+ (input_1_11_0*0.01))- ( (0.001*sub11)*0.09999999999999987))")
    sub13 = evaluate("( (sub12+ (input_1_12_0*0.01))- ( (0.001*sub12)*0.10000000000000009))")
    sub14 = evaluate("( (sub13+ (input_1_13_0*0.01))- ( (0.001*sub13)*0.09999999999999987))")
    sub15 = evaluate("( (sub14+ (input_1_14_0*0.01))- ( (0.001*sub14)*0.10000000000000009))")
    sub16 = evaluate("( (sub15+ (input_1_15_0*0.01))- ( (0.001*sub15)*0.10000000000000009))")
    sub17 = evaluate("( (sub16+ (input_1_16_0*0.01))- ( (0.001*sub16)*0.09999999999999987))")
    sub18 = evaluate("( (sub17+ (input_1_17_0*0.01))- ( (0.001*sub17)*0.10000000000000009))")
    sub19 = evaluate("( (sub18+ (input_1_18_0*0.01))- ( (0.001*sub18)*0.09999999999999987))")
    sub20 = evaluate("( (sub19+ (input_1_19_0*0.01))- ( (0.001*sub19)*0.10000000000000009))")
    sub21 = evaluate("( (sub20+ (input_1_20_0*0.01))- ( (0.001*sub20)*0.10000000000000009))")
    sub22 = evaluate("( (sub21+ (input_1_21_0*0.01))- ( (0.001*sub21)*0.10000000000000009))")
    sub23 = evaluate("( (sub22+ (input_1_22_0*0.01))- ( (0.001*sub22)*0.09999999999999964))")
    sub24 = evaluate("( (sub23+ (input_1_23_0*0.01))- ( (0.001*sub23)*0.10000000000000009))")
    sub25 = evaluate("( (sub24+ (input_1_24_0*0.01))- ( (0.001*sub24)*0.10000000000000009))")
    sub26 = evaluate("( (sub25+ (input_1_25_0*0.01))- ( (0.001*sub25)*0.10000000000000009))")
    sub27 = evaluate("( (sub26+ (input_1_26_0*0.01))- ( (0.001*sub26)*0.10000000000000009))")
    sub28 = evaluate("( (sub27+ (input_1_27_0*0.01))- ( (0.001*sub27)*0.09999999999999964))")
    sub29 = evaluate("( (sub28+ (input_1_28_0*0.01))- ( (0.001*sub28)*0.10000000000000009))")
    sub30 = evaluate("( (sub29+ (input_1_29_0*0.01))- ( (0.001*sub29)*0.10000000000000009))")
    sub31 = evaluate("( (sub30+ (input_1_30_0*0.01))- ( (0.001*sub30)*0.10000000000000009))")
    sub32 = evaluate("( (sub31+ (input_1_31_0*0.01))- ( (0.001*sub31)*0.10000000000000009))")
    sub33 = evaluate("( (sub32+ (input_1_32_0*0.01))- ( (0.001*sub32)*0.09999999999999964))")
    sub34 = evaluate("( (sub33+ (input_1_33_0*0.01))- ( (0.001*sub33)*0.10000000000000009))")
    sub35 = evaluate("( (sub34+ (input_1_34_0*0.01))- ( (0.001*sub34)*0.10000000000000009))")
    sub36 = evaluate("( (sub35+ (input_1_35_0*0.01))- ( (0.001*sub35)*0.10000000000000009))")
    sub37 = evaluate("( (sub36+ (input_1_36_0*0.01))- ( (0.001*sub36)*0.10000000000000009))")
    sub38 = evaluate("( (sub37+ (input_1_37_0*0.01))- ( (0.001*sub37)*0.09999999999999964))")
    sub39 = evaluate("( (sub38+ (input_1_38_0*0.01))- ( (0.001*sub38)*0.10000000000000009))")
    sub40 = evaluate("( (sub39+ (input_1_39_0*0.01))- ( (0.001*sub39)*0.10000000000000009))")
    sub41 = evaluate("( (sub40+ (input_1_40_0*0.01))- ( (0.001*sub40)*0.09999999999999964))")
    sub42 = evaluate("( (sub41+ (input_1_41_0*0.01))- ( (0.001*sub41)*0.10000000000000053))")
    sub43 = evaluate("( (sub42+ (input_1_42_0*0.01))- ( (0.001*sub42)*0.09999999999999964))")
    sub44 = evaluate("( (sub43+ (input_1_43_0*0.01))- ( (0.001*sub43)*0.10000000000000053))")
    sub45 = evaluate("( (sub44+ (input_1_44_0*0.01))- ( (0.001*sub44)*0.09999999999999964))")
    sub46 = evaluate("( (sub45+ (input_1_45_0*0.01))- ( (0.001*sub45)*0.09999999999999964))")
    sub47 = evaluate("( (sub46+ (input_1_46_0*0.01))- ( (0.001*sub46)*0.10000000000000053))")
    sub48 = evaluate("( (sub47+ (input_1_47_0*0.01))- ( (0.001*sub47)*0.09999999999999964))")
    sub49 = evaluate("( (sub48+ (input_1_48_0*0.01))- ( (0.001*sub48)*0.10000000000000053))")
    sub50 = evaluate("( (sub49+ (input_1_49_0*0.01))- ( (0.001*sub49)*0.09999999999999964))")
    add51 = evaluate("( (1+ ( (0.021046395486351097+sub50)*0.09999999999999964))+ (input_1_49_1*0.2))")
    add52 = evaluate("( (1+ ( (0.020901950349960913+sub47)*0.10000000000000053))+ (input_1_46_1*0.2))")
    add53 = evaluate("( (1+ ( (0.020855773529721826+sub46)*0.09999999999999964))+ (input_1_45_1*0.2))")
    add54 = evaluate("( (1+ ( (0.02076637900754313+sub44)*0.10000000000000053))+ (input_1_43_1*0.2))")
    add55 = evaluate("( (1+ ( (0.02068093195564701+sub42)*0.10000000000000053))+ (input_1_41_1*0.2))")
    add56 = evaluate("( (1+ ( (0.020639689473521117+sub41)*0.09999999999999964))+ (input_1_40_1*0.2))")
    add57 = evaluate("( (1+ ( (0.020599434750064056+sub40)*0.10000000000000009))+ (input_1_39_1*0.2))")
    add58 = evaluate("( (1+ ( (0.020484600103825704+sub37)*0.10000000000000009))+ (input_1_36_1*0.2))")
    add59 = evaluate("( (1+ ( (0.02044829938751084+sub36)*0.10000000000000009))+ (input_1_35_1*0.2))")
    add60 = evaluate("( (1+ ( (0.020345333900229575+sub33)*0.09999999999999964))+ (input_1_32_1*0.2))")
    add61 = evaluate("( (1+ ( (0.020312991950336673+sub32)*0.10000000000000009))+ (input_1_31_1*0.2))")
    add62 = evaluate("( (1+ ( (0.020251279655645275+sub30)*0.10000000000000009))+ (input_1_29_1*0.2))")
    add63 = evaluate("( (1+ ( (0.020139749827542446+sub26)*0.10000000000000009))+ (input_1_25_1*0.2))")
    add64 = evaluate("( (1+ ( (0.020066519761578673+sub23)*0.09999999999999964))+ (input_1_22_1*0.2))")
    add65 = evaluate("( (1+ ( (0.0200226648129058+sub21)*0.10000000000000009))+ (input_1_20_1*0.2))")
    add66 = evaluate("( (1+ ( (0.020002227762446635+sub20)*0.10000000000000009))+ (input_1_19_1*0.2))")
    add67 = evaluate("( (1+ ( (0.01998278472597332+sub19)*0.09999999999999987))+ (input_1_18_1*0.2))")
    add68 = evaluate("( (1+ ( (0.019900490208159222+sub14)*0.09999999999999987))+ (input_1_13_1*0.2))")
    add69 = evaluate("( (1+ ( (0.01987454095662866+sub12)*0.09999999999999987))+ (input_1_11_1*0.2))")
    add70 = evaluate("( (1+ ( (0.019852577325333926+sub10)*0.09999999999999998))+ (input_1_9_1*0.2))")
    add71 = evaluate("( (1+ ( (0.019843090865308635+sub9)*0.09999999999999998))+ (input_1_8_1*0.2))")
    add72 = evaluate("( (1+ ( (0.019834601708122325+sub8)*0.10000000000000009))+ (input_1_7_1*0.2))")
    add73 = evaluate("( (1+ ( (0.019810624096926296+sub4)*0.10000000000000003))+ (input_1_3_1*0.2))")
    add74 = evaluate("(1+ ( (0.019807125946415968+ (add2-mul3))*0.09999999999999998))")
    mul75 = evaluate("( (0.019804626896226418+ (add1- (mul0*0.1)))*0.1)")
    add76 = evaluate("(0.01980312724618267+ ( (0+ (input_1_0_0*0.01))-0.0))")
    add77 = evaluate("( (1+ (add76*0.1))+ (input_1_0_1*0.2))")
    mul78 = evaluate("( (100*add77)* ( (1+mul75)+ (input_1_1_1*0.2)))")
    mul79 = evaluate("( (mul78* (add74+ (input_1_2_1*0.2)))*add73)")
    add80 = evaluate("( (1+ ( (0.019815121048002284+sub5)*0.09999999999999998))+ (input_1_4_1*0.2))")
    add81 = evaluate("( (1+ ( (0.01982061649995878+sub6)*0.09999999999999998))+ (input_1_5_1*0.2))")
    add82 = evaluate("( (1+ ( (0.019827110153180574+sub7)*0.09999999999999998))+ (input_1_6_1*0.2))")
    mul83 = evaluate("( ( ( (mul79*add80)*add81)*add82)*add72)")
    add84 = evaluate("( (1+ ( (0.019863060788862557+sub11)*0.10000000000000009))+ (input_1_10_1*0.2))")
    mul85 = evaluate("( ( ( (mul83*add71)*add70)*add84)*add69)")
    add86 = evaluate("( (1+ ( (0.01988701752943629+sub13)*0.10000000000000009))+ (input_1_12_1*0.2))")
    add87 = evaluate("( (1+ ( (0.019914958693741127+sub15)*0.10000000000000009))+ (input_1_14_1*0.2))")
    add88 = evaluate("( (1+ ( (0.019930422687195398+sub16)*0.10000000000000009))+ (input_1_15_1*0.2))")
    mul89 = evaluate("( ( ( (mul85*add86)*add68)*add87)*add88)")
    add90 = evaluate("( (1+ ( (0.01994688188960527+sub17)*0.09999999999999987))+ (input_1_16_1*0.2))")
    add91 = evaluate("( (1+ ( (0.01996433600212367+sub18)*0.10000000000000009))+ (input_1_17_1*0.2))")
    mul92 = evaluate("( ( ( (mul89*add90)*add91)*add67)*add66)")
    add93 = evaluate("( (1+ ( (0.020044095578782617+sub22)*0.10000000000000009))+ (input_1_21_1*0.2))")
    add94 = evaluate("( (1+ ( (0.020089937062865132+sub24)*0.10000000000000009))+ (input_1_23_1*0.2))")
    mul95 = evaluate("( ( ( (mul92*add65)*add93)*add64)*add94)")
    add96 = evaluate("( (1+ ( (0.02011434718428291+sub25)*0.10000000000000009))+ (input_1_24_1*0.2))")
    add97 = evaluate("( (1+ ( (0.02016614469442393+sub27)*0.10000000000000009))+ (input_1_26_1*0.2))")
    add98 = evaluate("( (1+ ( (0.020193531486777085+sub28)*0.09999999999999964))+ (input_1_27_1*0.2))")
    mul99 = evaluate("( ( ( (mul95*add96)*add63)*add97)*add98)")
    add100 = evaluate("( (1+ ( (0.020221909906521236+sub29)*0.10000000000000009))+ (input_1_28_1*0.2))")
    add101 = evaluate("( (1+ ( (0.02028164043620774+sub31)*0.10000000000000009))+ (input_1_30_1*0.2))")
    mul102 = evaluate("( ( ( (mul99*add100)*add62)*add101)*add61)")
    add103 = evaluate("( (1+ ( (0.020378665988153574+sub34)*0.10000000000000009))+ (input_1_33_1*0.2))")
    add104 = evaluate("( (1+ ( (0.020412987916445312+sub35)*0.10000000000000009))+ (input_1_34_1*0.2))")
    mul105 = evaluate("( ( ( (mul102*add60)*add103)*add104)*add59)")
    add106 = evaluate("( (1+ ( (0.020521889767934957+sub38)*0.09999999999999964))+ (input_1_37_1*0.2))")
    add107 = evaluate("( (1+ ( (0.020560168082453117+sub39)*0.10000000000000009))+ (input_1_38_1*0.2))")
    mul108 = evaluate("( ( ( (mul105*add58)*add106)*add107)*add57)")
    add109 = evaluate("( (1+ ( (0.02072316189933383+sub43)*0.09999999999999964))+ (input_1_42_1*0.2))")
    mul110 = evaluate("( ( ( (mul108*add56)*add55)*add109)*add54)")
    add111 = evaluate("( (1+ ( (0.020810582983305747+sub45)*0.09999999999999964))+ (input_1_44_1*0.2))")
    add112 = evaluate("( (1+ ( (0.020949113147261875+sub48)*0.09999999999999964))+ (input_1_47_1*0.2))")
    mul113 = evaluate("( ( ( (mul110*add111)*add53)*add52)*add112)")
    add114 = evaluate("( (1+ ( (0.020997261624932803+sub49)*0.10000000000000053))+ (input_1_48_1*0.2))")
    #     maximum115 = evaluate(maximum(0,  ( ( (mul113*add114)*add51)-100)))
    maximum115= evaluate("mul113*add114*add51-100")
    return maximum115

# %%
# %%timeit
cal(np.random.normal(0,1,(100, 1000000)))
# Out:
# 3.44 s ± 8.81 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
def cal(input_1): 
    evaluate = ne.evaluate
    input_1_49_1= input_1[0]
    input_1_47_0= input_1[1]
    input_1_43_0= input_1[2]
    input_1_42_0= input_1[3]
    input_1_41_0= input_1[4]
    input_1_31_0= input_1[5]
    input_1_23_0= input_1[6]
    input_1_18_0= input_1[7]
    input_1_16_0= input_1[8]
    input_1_4_0= input_1[9]
    input_1_0_0= input_1[10]
    input_1_1_0= input_1[11]
    input_1_2_0= input_1[12]
    input_1_3_0= input_1[13]
    input_1_5_0= input_1[14]
    input_1_6_0= input_1[15]
    input_1_7_0= input_1[16]
    input_1_8_0= input_1[17]
    input_1_9_0= input_1[18]
    input_1_10_0= input_1[19]
    input_1_11_0= input_1[20]
    input_1_12_0= input_1[21]
    input_1_13_0= input_1[22]
    input_1_14_0= input_1[23]
    input_1_15_0= input_1[24]
    input_1_17_0= input_1[25]
    input_1_19_0= input_1[26]
    input_1_20_0= input_1[27]
    input_1_21_0= input_1[28]
    input_1_22_0= input_1[29]
    input_1_24_0= input_1[30]
    input_1_25_0= input_1[31]
    input_1_26_0= input_1[32]
    input_1_27_0= input_1[33]
    input_1_28_0= input_1[34]
    input_1_29_0= input_1[35]
    input_1_30_0= input_1[36]
    input_1_32_0= input_1[37]
    input_1_33_0= input_1[38]
    input_1_34_0= input_1[39]
    input_1_35_0= input_1[40]
    input_1_36_0= input_1[41]
    input_1_37_0= input_1[42]
    input_1_38_0= input_1[43]
    input_1_39_0= input_1[44]
    input_1_40_0= input_1[45]
    input_1_44_0= input_1[46]
    input_1_45_0= input_1[47]
    input_1_46_0= input_1[48]
    input_1_48_0= input_1[49]
    input_1_49_0= input_1[50]
    input_1_46_1= input_1[51]
    input_1_45_1= input_1[52]
    input_1_43_1= input_1[53]
    input_1_41_1= input_1[54]
    input_1_40_1= input_1[55]
    input_1_39_1= input_1[56]
    input_1_36_1= input_1[57]
    input_1_35_1= input_1[58]
    input_1_32_1= input_1[59]
    input_1_31_1= input_1[60]
    input_1_29_1= input_1[61]
    input_1_25_1= input_1[62]
    input_1_22_1= input_1[63]
    input_1_20_1= input_1[64]
    input_1_19_1= input_1[65]
    input_1_18_1= input_1[66]
    input_1_13_1= input_1[67]
    input_1_11_1= input_1[68]
    input_1_9_1= input_1[69]
    input_1_8_1= input_1[70]
    input_1_7_1= input_1[71]
    input_1_3_1= input_1[72]
    input_1_2_1= input_1[73]
    input_1_1_1= input_1[74]
    input_1_0_1= input_1[75]
    input_1_4_1= input_1[76]
    input_1_5_1= input_1[77]
    input_1_6_1= input_1[78]
    input_1_10_1= input_1[79]
    input_1_12_1= input_1[80]
    input_1_14_1= input_1[81]
    input_1_15_1= input_1[82]
    input_1_16_1= input_1[83]
    input_1_17_1= input_1[84]
    input_1_21_1= input_1[85]
    input_1_23_1= input_1[86]
    input_1_24_1= input_1[87]
    input_1_26_1= input_1[88]
    input_1_27_1= input_1[89]
    input_1_28_1= input_1[90]
    input_1_30_1= input_1[91]
    input_1_33_1= input_1[92]
    input_1_34_1= input_1[93]
    input_1_37_1= input_1[94]
    input_1_38_1= input_1[95]
    input_1_42_1= input_1[96]
    input_1_44_1= input_1[97]
    input_1_47_1= input_1[98]
    input_1_48_1= input_1[99]
    sub0 = evaluate("( ( ( (0+ (input_1_0_0*0.01))-0.0)+ (input_1_1_0*0.01))- ( (0.001* ( (0+ (input_1_0_0*0.01))-0.0))*0.1))")
    sub1 = evaluate("( ( ( (sub0+ (input_1_2_0*0.01))- ( (0.001*sub0)*0.09999999999999998))+ (input_1_3_0*0.01))- ( (0.001* ( (sub0+ (input_1_2_0*0.01))- ( (0.001*sub0)*0.09999999999999998)))*0.10000000000000003))")
    sub2 = evaluate("( ( ( (sub1+ (input_1_4_0*0.01))- ( (0.001*sub1)*0.09999999999999998))+ (input_1_5_0*0.01))- ( (0.001* ( (sub1+ (input_1_4_0*0.01))- ( (0.001*sub1)*0.09999999999999998)))*0.09999999999999998))")
    sub3 = evaluate("( ( ( (sub2+ (input_1_6_0*0.01))- ( (0.001*sub2)*0.09999999999999998))+ (input_1_7_0*0.01))- ( (0.001* ( (sub2+ (input_1_6_0*0.01))- ( (0.001*sub2)*0.09999999999999998)))*0.10000000000000009))")
    sub4 = evaluate("( ( ( (sub3+ (input_1_8_0*0.01))- ( (0.001*sub3)*0.09999999999999998))+ (input_1_9_0*0.01))- ( (0.001* ( (sub3+ (input_1_8_0*0.01))- ( (0.001*sub3)*0.09999999999999998)))*0.09999999999999998))")
    sub5 = evaluate("( ( ( (sub4+ (input_1_10_0*0.01))- ( (0.001*sub4)*0.10000000000000009))+ (input_1_11_0*0.01))- ( (0.001* ( (sub4+ (input_1_10_0*0.01))- ( (0.001*sub4)*0.10000000000000009)))*0.09999999999999987))")
    sub6 = evaluate("( ( ( (sub5+ (input_1_12_0*0.01))- ( (0.001*sub5)*0.10000000000000009))+ (input_1_13_0*0.01))- ( (0.001* ( (sub5+ (input_1_12_0*0.01))- ( (0.001*sub5)*0.10000000000000009)))*0.09999999999999987))")
    sub7 = evaluate("( ( ( (sub6+ (input_1_14_0*0.01))- ( (0.001*sub6)*0.10000000000000009))+ (input_1_15_0*0.01))- ( (0.001* ( (sub6+ (input_1_14_0*0.01))- ( (0.001*sub6)*0.10000000000000009)))*0.10000000000000009))")
    sub8 = evaluate("( ( ( (sub7+ (input_1_16_0*0.01))- ( (0.001*sub7)*0.09999999999999987))+ (input_1_17_0*0.01))- ( (0.001* ( (sub7+ (input_1_16_0*0.01))- ( (0.001*sub7)*0.09999999999999987)))*0.10000000000000009))")
    sub9 = evaluate("( ( ( (sub8+ (input_1_18_0*0.01))- ( (0.001*sub8)*0.09999999999999987))+ (input_1_19_0*0.01))- ( (0.001* ( (sub8+ (input_1_18_0*0.01))- ( (0.001*sub8)*0.09999999999999987)))*0.10000000000000009))")
    sub10 = evaluate("( ( ( (sub9+ (input_1_20_0*0.01))- ( (0.001*sub9)*0.10000000000000009))+ (input_1_21_0*0.01))- ( (0.001* ( (sub9+ (input_1_20_0*0.01))- ( (0.001*sub9)*0.10000000000000009)))*0.10000000000000009))")
    sub11 = evaluate("( ( ( (sub10+ (input_1_22_0*0.01))- ( (0.001*sub10)*0.09999999999999964))+ (input_1_23_0*0.01))- ( (0.001* ( (sub10+ (input_1_22_0*0.01))- ( (0.001*sub10)*0.09999999999999964)))*0.10000000000000009))")
    sub12 = evaluate("( ( ( (sub11+ (input_1_24_0*0.01))- ( (0.001*sub11)*0.10000000000000009))+ (input_1_25_0*0.01))- ( (0.001* ( (sub11+ (input_1_24_0*0.01))- ( (0.001*sub11)*0.10000000000000009)))*0.10000000000000009))")
    sub13 = evaluate("( ( ( (sub12+ (input_1_26_0*0.01))- ( (0.001*sub12)*0.10000000000000009))+ (input_1_27_0*0.01))- ( (0.001* ( (sub12+ (input_1_26_0*0.01))- ( (0.001*sub12)*0.10000000000000009)))*0.09999999999999964))")
    sub14 = evaluate("( ( ( (sub13+ (input_1_28_0*0.01))- ( (0.001*sub13)*0.10000000000000009))+ (input_1_29_0*0.01))- ( (0.001* ( (sub13+ (input_1_28_0*0.01))- ( (0.001*sub13)*0.10000000000000009)))*0.10000000000000009))")
    sub15 = evaluate("( ( ( (sub14+ (input_1_30_0*0.01))- ( (0.001*sub14)*0.10000000000000009))+ (input_1_31_0*0.01))- ( (0.001* ( (sub14+ (input_1_30_0*0.01))- ( (0.001*sub14)*0.10000000000000009)))*0.10000000000000009))")
    sub16 = evaluate("( ( ( (sub15+ (input_1_32_0*0.01))- ( (0.001*sub15)*0.09999999999999964))+ (input_1_33_0*0.01))- ( (0.001* ( (sub15+ (input_1_32_0*0.01))- ( (0.001*sub15)*0.09999999999999964)))*0.10000000000000009))")
    sub17 = evaluate("( ( ( (sub16+ (input_1_34_0*0.01))- ( (0.001*sub16)*0.10000000000000009))+ (input_1_35_0*0.01))- ( (0.001* ( (sub16+ (input_1_34_0*0.01))- ( (0.001*sub16)*0.10000000000000009)))*0.10000000000000009))")
    sub18 = evaluate("( ( ( (sub17+ (input_1_36_0*0.01))- ( (0.001*sub17)*0.10000000000000009))+ (input_1_37_0*0.01))- ( (0.001* ( (sub17+ (input_1_36_0*0.01))- ( (0.001*sub17)*0.10000000000000009)))*0.09999999999999964))")
    sub19 = evaluate("( ( ( (sub18+ (input_1_38_0*0.01))- ( (0.001*sub18)*0.10000000000000009))+ (input_1_39_0*0.01))- ( (0.001* ( (sub18+ (input_1_38_0*0.01))- ( (0.001*sub18)*0.10000000000000009)))*0.10000000000000009))")
    sub20 = evaluate("( ( ( (sub19+ (input_1_40_0*0.01))- ( (0.001*sub19)*0.09999999999999964))+ (input_1_41_0*0.01))- ( (0.001* ( (sub19+ (input_1_40_0*0.01))- ( (0.001*sub19)*0.09999999999999964)))*0.10000000000000053))")
    sub21 = evaluate("( ( ( (sub20+ (input_1_42_0*0.01))- ( (0.001*sub20)*0.09999999999999964))+ (input_1_43_0*0.01))- ( (0.001* ( (sub20+ (input_1_42_0*0.01))- ( (0.001*sub20)*0.09999999999999964)))*0.10000000000000053))")
    sub22 = evaluate("( ( ( (sub21+ (input_1_44_0*0.01))- ( (0.001*sub21)*0.09999999999999964))+ (input_1_45_0*0.01))- ( (0.001* ( (sub21+ (input_1_44_0*0.01))- ( (0.001*sub21)*0.09999999999999964)))*0.09999999999999964))")
    sub23 = evaluate("( ( ( (sub22+ (input_1_46_0*0.01))- ( (0.001*sub22)*0.10000000000000053))+ (input_1_47_0*0.01))- ( (0.001* ( (sub22+ (input_1_46_0*0.01))- ( (0.001*sub22)*0.10000000000000053)))*0.09999999999999964))")
    sub24 = evaluate("( ( ( (sub23+ (input_1_48_0*0.01))- ( (0.001*sub23)*0.10000000000000053))+ (input_1_49_0*0.01))- ( (0.001* ( (sub23+ (input_1_48_0*0.01))- ( (0.001*sub23)*0.10000000000000053)))*0.09999999999999964))")
    add25 = evaluate("( (1+ ( (0.020901950349960913+ ( (sub22+ (input_1_46_0*0.01))- ( (0.001*sub22)*0.10000000000000053)))*0.10000000000000053))+ (input_1_46_1*0.2))")
    add26 = evaluate("( (1+ ( (0.020639689473521117+ ( (sub19+ (input_1_40_0*0.01))- ( (0.001*sub19)*0.09999999999999964)))*0.09999999999999964))+ (input_1_40_1*0.2))")
    add27 = evaluate("( (1+ ( (0.020484600103825704+ ( (sub17+ (input_1_36_0*0.01))- ( (0.001*sub17)*0.10000000000000009)))*0.10000000000000009))+ (input_1_36_1*0.2))")
    add28 = evaluate("( (1+ ( (0.020345333900229575+ ( (sub15+ (input_1_32_0*0.01))- ( (0.001*sub15)*0.09999999999999964)))*0.09999999999999964))+ (input_1_32_1*0.2))")
    add29 = evaluate("( (1+ ( (0.020066519761578673+ ( (sub10+ (input_1_22_0*0.01))- ( (0.001*sub10)*0.09999999999999964)))*0.09999999999999964))+ (input_1_22_1*0.2))")
    add30 = evaluate("( (1+ ( (0.0200226648129058+ ( (sub9+ (input_1_20_0*0.01))- ( (0.001*sub9)*0.10000000000000009)))*0.10000000000000009))+ (input_1_20_1*0.2))")
    add31 = evaluate("( (1+ ( (0.01998278472597332+ ( (sub8+ (input_1_18_0*0.01))- ( (0.001*sub8)*0.09999999999999987)))*0.09999999999999987))+ (input_1_18_1*0.2))")
    add32 = evaluate("( (1+ ( (0.019843090865308635+ ( (sub3+ (input_1_8_0*0.01))- ( (0.001*sub3)*0.09999999999999998)))*0.09999999999999998))+ (input_1_8_1*0.2))")
    add33 = evaluate("( (1+ ( (0.019807125946415968+ ( (sub0+ (input_1_2_0*0.01))- ( (0.001*sub0)*0.09999999999999998)))*0.09999999999999998))+ (input_1_2_1*0.2))")
    mul34 = evaluate("( (100* ( (1+ ( (0.01980312724618267+ ( (0+ (input_1_0_0*0.01))-0.0))*0.1))+ (input_1_0_1*0.2)))* ( (1+ ( (0.019804626896226418+sub0)*0.1))+ (input_1_1_1*0.2)))")
    add35 = evaluate("( (1+ ( (0.019815121048002284+ ( (sub1+ (input_1_4_0*0.01))- ( (0.001*sub1)*0.09999999999999998)))*0.09999999999999998))+ (input_1_4_1*0.2))")
    mul36 = evaluate("( ( ( (mul34*add33)* ( (1+ ( (0.019810624096926296+sub1)*0.10000000000000003))+ (input_1_3_1*0.2)))*add35)* ( (1+ ( (0.01982061649995878+sub2)*0.09999999999999998))+ (input_1_5_1*0.2)))")
    add37 = evaluate("( (1+ ( (0.019827110153180574+ ( (sub2+ (input_1_6_0*0.01))- ( (0.001*sub2)*0.09999999999999998)))*0.09999999999999998))+ (input_1_6_1*0.2))")
    mul38 = evaluate("( ( ( (mul36*add37)* ( (1+ ( (0.019834601708122325+sub3)*0.10000000000000009))+ (input_1_7_1*0.2)))*add32)* ( (1+ ( (0.019852577325333926+sub4)*0.09999999999999998))+ (input_1_9_1*0.2)))")
    add39 = evaluate("( (1+ ( (0.019863060788862557+ ( (sub4+ (input_1_10_0*0.01))- ( (0.001*sub4)*0.10000000000000009)))*0.10000000000000009))+ (input_1_10_1*0.2))")
    add40 = evaluate("( (1+ ( (0.01988701752943629+ ( (sub5+ (input_1_12_0*0.01))- ( (0.001*sub5)*0.10000000000000009)))*0.10000000000000009))+ (input_1_12_1*0.2))")
    mul41 = evaluate("( ( ( (mul38*add39)* ( (1+ ( (0.01987454095662866+sub5)*0.09999999999999987))+ (input_1_11_1*0.2)))*add40)* ( (1+ ( (0.019900490208159222+sub6)*0.09999999999999987))+ (input_1_13_1*0.2)))")
    add42 = evaluate("( (1+ ( (0.019914958693741127+ ( (sub6+ (input_1_14_0*0.01))- ( (0.001*sub6)*0.10000000000000009)))*0.10000000000000009))+ (input_1_14_1*0.2))")
    add43 = evaluate("( (1+ ( (0.01994688188960527+ ( (sub7+ (input_1_16_0*0.01))- ( (0.001*sub7)*0.09999999999999987)))*0.09999999999999987))+ (input_1_16_1*0.2))")
    mul44 = evaluate("( ( ( (mul41*add42)* ( (1+ ( (0.019930422687195398+sub7)*0.10000000000000009))+ (input_1_15_1*0.2)))*add43)* ( (1+ ( (0.01996433600212367+sub8)*0.10000000000000009))+ (input_1_17_1*0.2)))")
    mul45 = evaluate("( ( ( (mul44*add31)* ( (1+ ( (0.020002227762446635+sub9)*0.10000000000000009))+ (input_1_19_1*0.2)))*add30)* ( (1+ ( (0.020044095578782617+sub10)*0.10000000000000009))+ (input_1_21_1*0.2)))")
    add46 = evaluate("( (1+ ( (0.02011434718428291+ ( (sub11+ (input_1_24_0*0.01))- ( (0.001*sub11)*0.10000000000000009)))*0.10000000000000009))+ (input_1_24_1*0.2))")
    mul47 = evaluate("( ( ( (mul45*add29)* ( (1+ ( (0.020089937062865132+sub11)*0.10000000000000009))+ (input_1_23_1*0.2)))*add46)* ( (1+ ( (0.020139749827542446+sub12)*0.10000000000000009))+ (input_1_25_1*0.2)))")
    add48 = evaluate("( (1+ ( (0.02016614469442393+ ( (sub12+ (input_1_26_0*0.01))- ( (0.001*sub12)*0.10000000000000009)))*0.10000000000000009))+ (input_1_26_1*0.2))")
    add49 = evaluate("( (1+ ( (0.020221909906521236+ ( (sub13+ (input_1_28_0*0.01))- ( (0.001*sub13)*0.10000000000000009)))*0.10000000000000009))+ (input_1_28_1*0.2))")
    mul50 = evaluate("( ( ( (mul47*add48)* ( (1+ ( (0.020193531486777085+sub13)*0.09999999999999964))+ (input_1_27_1*0.2)))*add49)* ( (1+ ( (0.020251279655645275+sub14)*0.10000000000000009))+ (input_1_29_1*0.2)))")
    add51 = evaluate("( (1+ ( (0.02028164043620774+ ( (sub14+ (input_1_30_0*0.01))- ( (0.001*sub14)*0.10000000000000009)))*0.10000000000000009))+ (input_1_30_1*0.2))")
    mul52 = evaluate("( ( ( (mul50*add51)* ( (1+ ( (0.020312991950336673+sub15)*0.10000000000000009))+ (input_1_31_1*0.2)))*add28)* ( (1+ ( (0.020378665988153574+sub16)*0.10000000000000009))+ (input_1_33_1*0.2)))")
    add53 = evaluate("( (1+ ( (0.020412987916445312+ ( (sub16+ (input_1_34_0*0.01))- ( (0.001*sub16)*0.10000000000000009)))*0.10000000000000009))+ (input_1_34_1*0.2))")
    mul54 = evaluate("( ( ( (mul52*add53)* ( (1+ ( (0.02044829938751084+sub17)*0.10000000000000009))+ (input_1_35_1*0.2)))*add27)* ( (1+ ( (0.020521889767934957+sub18)*0.09999999999999964))+ (input_1_37_1*0.2)))")
    add55 = evaluate("( (1+ ( (0.020560168082453117+ ( (sub18+ (input_1_38_0*0.01))- ( (0.001*sub18)*0.10000000000000009)))*0.10000000000000009))+ (input_1_38_1*0.2))")
    mul56 = evaluate("( ( ( (mul54*add55)* ( (1+ ( (0.020599434750064056+sub19)*0.10000000000000009))+ (input_1_39_1*0.2)))*add26)* ( (1+ ( (0.02068093195564701+sub20)*0.10000000000000053))+ (input_1_41_1*0.2)))")
    add57 = evaluate("( (1+ ( (0.02072316189933383+ ( (sub20+ (input_1_42_0*0.01))- ( (0.001*sub20)*0.09999999999999964)))*0.09999999999999964))+ (input_1_42_1*0.2))")
    add58 = evaluate("( (1+ ( (0.020810582983305747+ ( (sub21+ (input_1_44_0*0.01))- ( (0.001*sub21)*0.09999999999999964)))*0.09999999999999964))+ (input_1_44_1*0.2))")
    mul59 = evaluate("( ( ( (mul56*add57)* ( (1+ ( (0.02076637900754313+sub21)*0.10000000000000053))+ (input_1_43_1*0.2)))*add58)* ( (1+ ( (0.020855773529721826+sub22)*0.09999999999999964))+ (input_1_45_1*0.2)))")
    add60 = evaluate("( (1+ ( (0.020997261624932803+ ( (sub23+ (input_1_48_0*0.01))- ( (0.001*sub23)*0.10000000000000053)))*0.10000000000000053))+ (input_1_48_1*0.2))")
    mul61 = evaluate("( ( ( (mul59*add25)* ( (1+ ( (0.020949113147261875+sub23)*0.09999999999999964))+ (input_1_47_1*0.2)))*add60)* ( (1+ ( (0.021046395486351097+sub24)*0.09999999999999964))+ (input_1_49_1*0.2)))")
    maximum62 = evaluate("(mul61-100)")
    return maximum62

# %%
# %%timeit
cal(np.random.normal(0,1,(100, 1000000)))
# Out:
# 3.34 s ± 10.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
def cal(input_1): 
    evaluate = ne.evaluate
    input_1_49_1= input_1[0]
    input_1_47_0= input_1[1]
    input_1_43_0= input_1[2]
    input_1_42_0= input_1[3]
    input_1_41_0= input_1[4]
    input_1_31_0= input_1[5]
    input_1_23_0= input_1[6]
    input_1_18_0= input_1[7]
    input_1_16_0= input_1[8]
    input_1_4_0= input_1[9]
    input_1_0_0= input_1[10]
    input_1_1_0= input_1[11]
    input_1_2_0= input_1[12]
    input_1_3_0= input_1[13]
    input_1_5_0= input_1[14]
    input_1_6_0= input_1[15]
    input_1_7_0= input_1[16]
    input_1_8_0= input_1[17]
    input_1_9_0= input_1[18]
    input_1_10_0= input_1[19]
    input_1_11_0= input_1[20]
    input_1_12_0= input_1[21]
    input_1_13_0= input_1[22]
    input_1_14_0= input_1[23]
    input_1_15_0= input_1[24]
    input_1_17_0= input_1[25]
    input_1_19_0= input_1[26]
    input_1_20_0= input_1[27]
    input_1_21_0= input_1[28]
    input_1_22_0= input_1[29]
    input_1_24_0= input_1[30]
    input_1_25_0= input_1[31]
    input_1_26_0= input_1[32]
    input_1_27_0= input_1[33]
    input_1_28_0= input_1[34]
    input_1_29_0= input_1[35]
    input_1_30_0= input_1[36]
    input_1_32_0= input_1[37]
    input_1_33_0= input_1[38]
    input_1_34_0= input_1[39]
    input_1_35_0= input_1[40]
    input_1_36_0= input_1[41]
    input_1_37_0= input_1[42]
    input_1_38_0= input_1[43]
    input_1_39_0= input_1[44]
    input_1_40_0= input_1[45]
    input_1_44_0= input_1[46]
    input_1_45_0= input_1[47]
    input_1_46_0= input_1[48]
    input_1_48_0= input_1[49]
    input_1_49_0= input_1[50]
    input_1_46_1= input_1[51]
    input_1_45_1= input_1[52]
    input_1_43_1= input_1[53]
    input_1_41_1= input_1[54]
    input_1_40_1= input_1[55]
    input_1_39_1= input_1[56]
    input_1_36_1= input_1[57]
    input_1_35_1= input_1[58]
    input_1_32_1= input_1[59]
    input_1_31_1= input_1[60]
    input_1_29_1= input_1[61]
    input_1_25_1= input_1[62]
    input_1_22_1= input_1[63]
    input_1_20_1= input_1[64]
    input_1_19_1= input_1[65]
    input_1_18_1= input_1[66]
    input_1_13_1= input_1[67]
    input_1_11_1= input_1[68]
    input_1_9_1= input_1[69]
    input_1_8_1= input_1[70]
    input_1_7_1= input_1[71]
    input_1_3_1= input_1[72]
    input_1_2_1= input_1[73]
    input_1_1_1= input_1[74]
    input_1_0_1= input_1[75]
    input_1_4_1= input_1[76]
    input_1_5_1= input_1[77]
    input_1_6_1= input_1[78]
    input_1_10_1= input_1[79]
    input_1_12_1= input_1[80]
    input_1_14_1= input_1[81]
    input_1_15_1= input_1[82]
    input_1_16_1= input_1[83]
    input_1_17_1= input_1[84]
    input_1_21_1= input_1[85]
    input_1_23_1= input_1[86]
    input_1_24_1= input_1[87]
    input_1_26_1= input_1[88]
    input_1_27_1= input_1[89]
    input_1_28_1= input_1[90]
    input_1_30_1= input_1[91]
    input_1_33_1= input_1[92]
    input_1_34_1= input_1[93]
    input_1_37_1= input_1[94]
    input_1_38_1= input_1[95]
    input_1_42_1= input_1[96]
    input_1_44_1= input_1[97]
    input_1_47_1= input_1[98]
    input_1_48_1= input_1[99]
    sub0 = evaluate("( ( ( ( ( ( ( (0+ (input_1_0_0*0.01))-0.0)+ (input_1_1_0*0.01))- ( (0.001* ( (0+ (input_1_0_0*0.01))-0.0))*0.1))+ (input_1_2_0*0.01))- ( (0.001* ( ( ( (0+ (input_1_0_0*0.01))-0.0)+ (input_1_1_0*0.01))- ( (0.001* ( (0+ (input_1_0_0*0.01))-0.0))*0.1)))*0.09999999999999998))+ (input_1_3_0*0.01))- ( (0.001* ( ( ( ( ( (0+ (input_1_0_0*0.01))-0.0)+ (input_1_1_0*0.01))- ( (0.001* ( (0+ (input_1_0_0*0.01))-0.0))*0.1))+ (input_1_2_0*0.01))- ( (0.001* ( ( ( (0+ (input_1_0_0*0.01))-0.0)+ (input_1_1_0*0.01))- ( (0.001* ( (0+ (input_1_0_0*0.01))-0.0))*0.1)))*0.09999999999999998)))*0.10000000000000003))")
    sub1 = evaluate("( ( ( ( ( (sub0+ (input_1_4_0*0.01))- ( (0.001*sub0)*0.09999999999999998))+ (input_1_5_0*0.01))- ( (0.001* ( (sub0+ (input_1_4_0*0.01))- ( (0.001*sub0)*0.09999999999999998)))*0.09999999999999998))+ (input_1_6_0*0.01))- ( (0.001* ( ( ( (sub0+ (input_1_4_0*0.01))- ( (0.001*sub0)*0.09999999999999998))+ (input_1_5_0*0.01))- ( (0.001* ( (sub0+ (input_1_4_0*0.01))- ( (0.001*sub0)*0.09999999999999998)))*0.09999999999999998)))*0.09999999999999998))")
    sub2 = evaluate("( ( ( ( ( (sub1+ (input_1_7_0*0.01))- ( (0.001*sub1)*0.10000000000000009))+ (input_1_8_0*0.01))- ( (0.001* ( (sub1+ (input_1_7_0*0.01))- ( (0.001*sub1)*0.10000000000000009)))*0.09999999999999998))+ (input_1_9_0*0.01))- ( (0.001* ( ( ( (sub1+ (input_1_7_0*0.01))- ( (0.001*sub1)*0.10000000000000009))+ (input_1_8_0*0.01))- ( (0.001* ( (sub1+ (input_1_7_0*0.01))- ( (0.001*sub1)*0.10000000000000009)))*0.09999999999999998)))*0.09999999999999998))")
    sub3 = evaluate("( ( ( ( ( (sub2+ (input_1_10_0*0.01))- ( (0.001*sub2)*0.10000000000000009))+ (input_1_11_0*0.01))- ( (0.001* ( (sub2+ (input_1_10_0*0.01))- ( (0.001*sub2)*0.10000000000000009)))*0.09999999999999987))+ (input_1_12_0*0.01))- ( (0.001* ( ( ( (sub2+ (input_1_10_0*0.01))- ( (0.001*sub2)*0.10000000000000009))+ (input_1_11_0*0.01))- ( (0.001* ( (sub2+ (input_1_10_0*0.01))- ( (0.001*sub2)*0.10000000000000009)))*0.09999999999999987)))*0.10000000000000009))")
    sub4 = evaluate("( ( ( ( ( (sub3+ (input_1_13_0*0.01))- ( (0.001*sub3)*0.09999999999999987))+ (input_1_14_0*0.01))- ( (0.001* ( (sub3+ (input_1_13_0*0.01))- ( (0.001*sub3)*0.09999999999999987)))*0.10000000000000009))+ (input_1_15_0*0.01))- ( (0.001* ( ( ( (sub3+ (input_1_13_0*0.01))- ( (0.001*sub3)*0.09999999999999987))+ (input_1_14_0*0.01))- ( (0.001* ( (sub3+ (input_1_13_0*0.01))- ( (0.001*sub3)*0.09999999999999987)))*0.10000000000000009)))*0.10000000000000009))")
    sub5 = evaluate("( ( ( ( ( (sub4+ (input_1_16_0*0.01))- ( (0.001*sub4)*0.09999999999999987))+ (input_1_17_0*0.01))- ( (0.001* ( (sub4+ (input_1_16_0*0.01))- ( (0.001*sub4)*0.09999999999999987)))*0.10000000000000009))+ (input_1_18_0*0.01))- ( (0.001* ( ( ( (sub4+ (input_1_16_0*0.01))- ( (0.001*sub4)*0.09999999999999987))+ (input_1_17_0*0.01))- ( (0.001* ( (sub4+ (input_1_16_0*0.01))- ( (0.001*sub4)*0.09999999999999987)))*0.10000000000000009)))*0.09999999999999987))")
    sub6 = evaluate("( ( ( ( ( (sub5+ (input_1_19_0*0.01))- ( (0.001*sub5)*0.10000000000000009))+ (input_1_20_0*0.01))- ( (0.001* ( (sub5+ (input_1_19_0*0.01))- ( (0.001*sub5)*0.10000000000000009)))*0.10000000000000009))+ (input_1_21_0*0.01))- ( (0.001* ( ( ( (sub5+ (input_1_19_0*0.01))- ( (0.001*sub5)*0.10000000000000009))+ (input_1_20_0*0.01))- ( (0.001* ( (sub5+ (input_1_19_0*0.01))- ( (0.001*sub5)*0.10000000000000009)))*0.10000000000000009)))*0.10000000000000009))")
    sub7 = evaluate("( ( ( ( ( (sub6+ (input_1_22_0*0.01))- ( (0.001*sub6)*0.09999999999999964))+ (input_1_23_0*0.01))- ( (0.001* ( (sub6+ (input_1_22_0*0.01))- ( (0.001*sub6)*0.09999999999999964)))*0.10000000000000009))+ (input_1_24_0*0.01))- ( (0.001* ( ( ( (sub6+ (input_1_22_0*0.01))- ( (0.001*sub6)*0.09999999999999964))+ (input_1_23_0*0.01))- ( (0.001* ( (sub6+ (input_1_22_0*0.01))- ( (0.001*sub6)*0.09999999999999964)))*0.10000000000000009)))*0.10000000000000009))")
    sub8 = evaluate("( ( ( ( ( (sub7+ (input_1_25_0*0.01))- ( (0.001*sub7)*0.10000000000000009))+ (input_1_26_0*0.01))- ( (0.001* ( (sub7+ (input_1_25_0*0.01))- ( (0.001*sub7)*0.10000000000000009)))*0.10000000000000009))+ (input_1_27_0*0.01))- ( (0.001* ( ( ( (sub7+ (input_1_25_0*0.01))- ( (0.001*sub7)*0.10000000000000009))+ (input_1_26_0*0.01))- ( (0.001* ( (sub7+ (input_1_25_0*0.01))- ( (0.001*sub7)*0.10000000000000009)))*0.10000000000000009)))*0.09999999999999964))")
    sub9 = evaluate("( ( ( ( ( (sub8+ (input_1_28_0*0.01))- ( (0.001*sub8)*0.10000000000000009))+ (input_1_29_0*0.01))- ( (0.001* ( (sub8+ (input_1_28_0*0.01))- ( (0.001*sub8)*0.10000000000000009)))*0.10000000000000009))+ (input_1_30_0*0.01))- ( (0.001* ( ( ( (sub8+ (input_1_28_0*0.01))- ( (0.001*sub8)*0.10000000000000009))+ (input_1_29_0*0.01))- ( (0.001* ( (sub8+ (input_1_28_0*0.01))- ( (0.001*sub8)*0.10000000000000009)))*0.10000000000000009)))*0.10000000000000009))")
    sub10 = evaluate("( ( ( ( ( (sub9+ (input_1_31_0*0.01))- ( (0.001*sub9)*0.10000000000000009))+ (input_1_32_0*0.01))- ( (0.001* ( (sub9+ (input_1_31_0*0.01))- ( (0.001*sub9)*0.10000000000000009)))*0.09999999999999964))+ (input_1_33_0*0.01))- ( (0.001* ( ( ( (sub9+ (input_1_31_0*0.01))- ( (0.001*sub9)*0.10000000000000009))+ (input_1_32_0*0.01))- ( (0.001* ( (sub9+ (input_1_31_0*0.01))- ( (0.001*sub9)*0.10000000000000009)))*0.09999999999999964)))*0.10000000000000009))")
    sub11 = evaluate("( ( ( ( ( (sub10+ (input_1_34_0*0.01))- ( (0.001*sub10)*0.10000000000000009))+ (input_1_35_0*0.01))- ( (0.001* ( (sub10+ (input_1_34_0*0.01))- ( (0.001*sub10)*0.10000000000000009)))*0.10000000000000009))+ (input_1_36_0*0.01))- ( (0.001* ( ( ( (sub10+ (input_1_34_0*0.01))- ( (0.001*sub10)*0.10000000000000009))+ (input_1_35_0*0.01))- ( (0.001* ( (sub10+ (input_1_34_0*0.01))- ( (0.001*sub10)*0.10000000000000009)))*0.10000000000000009)))*0.10000000000000009))")
    sub12 = evaluate("( ( ( ( ( (sub11+ (input_1_37_0*0.01))- ( (0.001*sub11)*0.09999999999999964))+ (input_1_38_0*0.01))- ( (0.001* ( (sub11+ (input_1_37_0*0.01))- ( (0.001*sub11)*0.09999999999999964)))*0.10000000000000009))+ (input_1_39_0*0.01))- ( (0.001* ( ( ( (sub11+ (input_1_37_0*0.01))- ( (0.001*sub11)*0.09999999999999964))+ (input_1_38_0*0.01))- ( (0.001* ( (sub11+ (input_1_37_0*0.01))- ( (0.001*sub11)*0.09999999999999964)))*0.10000000000000009)))*0.10000000000000009))")
    sub13 = evaluate("( ( ( ( ( (sub12+ (input_1_40_0*0.01))- ( (0.001*sub12)*0.09999999999999964))+ (input_1_41_0*0.01))- ( (0.001* ( (sub12+ (input_1_40_0*0.01))- ( (0.001*sub12)*0.09999999999999964)))*0.10000000000000053))+ (input_1_42_0*0.01))- ( (0.001* ( ( ( (sub12+ (input_1_40_0*0.01))- ( (0.001*sub12)*0.09999999999999964))+ (input_1_41_0*0.01))- ( (0.001* ( (sub12+ (input_1_40_0*0.01))- ( (0.001*sub12)*0.09999999999999964)))*0.10000000000000053)))*0.09999999999999964))")
    sub14 = evaluate("( ( ( ( ( (sub13+ (input_1_43_0*0.01))- ( (0.001*sub13)*0.10000000000000053))+ (input_1_44_0*0.01))- ( (0.001* ( (sub13+ (input_1_43_0*0.01))- ( (0.001*sub13)*0.10000000000000053)))*0.09999999999999964))+ (input_1_45_0*0.01))- ( (0.001* ( ( ( (sub13+ (input_1_43_0*0.01))- ( (0.001*sub13)*0.10000000000000053))+ (input_1_44_0*0.01))- ( (0.001* ( (sub13+ (input_1_43_0*0.01))- ( (0.001*sub13)*0.10000000000000053)))*0.09999999999999964)))*0.09999999999999964))")
    sub15 = evaluate("( ( ( ( ( (sub14+ (input_1_46_0*0.01))- ( (0.001*sub14)*0.10000000000000053))+ (input_1_47_0*0.01))- ( (0.001* ( (sub14+ (input_1_46_0*0.01))- ( (0.001*sub14)*0.10000000000000053)))*0.09999999999999964))+ (input_1_48_0*0.01))- ( (0.001* ( ( ( (sub14+ (input_1_46_0*0.01))- ( (0.001*sub14)*0.10000000000000053))+ (input_1_47_0*0.01))- ( (0.001* ( (sub14+ (input_1_46_0*0.01))- ( (0.001*sub14)*0.10000000000000053)))*0.09999999999999964)))*0.10000000000000053))")
    add16 = evaluate("(1+ ( (0.019807125946415968+ ( ( ( ( ( (0+ (input_1_0_0*0.01))-0.0)+ (input_1_1_0*0.01))- ( (0.001* ( (0+ (input_1_0_0*0.01))-0.0))*0.1))+ (input_1_2_0*0.01))- ( (0.001* ( ( ( (0+ (input_1_0_0*0.01))-0.0)+ (input_1_1_0*0.01))- ( (0.001* ( (0+ (input_1_0_0*0.01))-0.0))*0.1)))*0.09999999999999998)))*0.09999999999999998))")
    mul17 = evaluate("( ( ( (100* ( (1+ ( (0.01980312724618267+ ( (0+ (input_1_0_0*0.01))-0.0))*0.1))+ (input_1_0_1*0.2)))* ( (1+ ( (0.019804626896226418+ ( ( ( (0+ (input_1_0_0*0.01))-0.0)+ (input_1_1_0*0.01))- ( (0.001* ( (0+ (input_1_0_0*0.01))-0.0))*0.1)))*0.1))+ (input_1_1_1*0.2)))* (add16+ (input_1_2_1*0.2)))* ( (1+ ( (0.019810624096926296+sub0)*0.10000000000000003))+ (input_1_3_1*0.2)))")
    mul18 = evaluate("( (mul17* ( (1+ ( (0.019815121048002284+ ( (sub0+ (input_1_4_0*0.01))- ( (0.001*sub0)*0.09999999999999998)))*0.09999999999999998))+ (input_1_4_1*0.2)))* ( (1+ ( (0.01982061649995878+ ( ( ( (sub0+ (input_1_4_0*0.01))- ( (0.001*sub0)*0.09999999999999998))+ (input_1_5_0*0.01))- ( (0.001* ( (sub0+ (input_1_4_0*0.01))- ( (0.001*sub0)*0.09999999999999998)))*0.09999999999999998)))*0.09999999999999998))+ (input_1_5_1*0.2)))")
    mul19 = evaluate("( ( (mul18* ( (1+ ( (0.019827110153180574+sub1)*0.09999999999999998))+ (input_1_6_1*0.2)))* ( (1+ ( (0.019834601708122325+ ( (sub1+ (input_1_7_0*0.01))- ( (0.001*sub1)*0.10000000000000009)))*0.10000000000000009))+ (input_1_7_1*0.2)))* ( (1+ ( (0.019843090865308635+ ( ( ( (sub1+ (input_1_7_0*0.01))- ( (0.001*sub1)*0.10000000000000009))+ (input_1_8_0*0.01))- ( (0.001* ( (sub1+ (input_1_7_0*0.01))- ( (0.001*sub1)*0.10000000000000009)))*0.09999999999999998)))*0.09999999999999998))+ (input_1_8_1*0.2)))")
    mul20 = evaluate("( ( (mul19* ( (1+ ( (0.019852577325333926+sub2)*0.09999999999999998))+ (input_1_9_1*0.2)))* ( (1+ ( (0.019863060788862557+ ( (sub2+ (input_1_10_0*0.01))- ( (0.001*sub2)*0.10000000000000009)))*0.10000000000000009))+ (input_1_10_1*0.2)))* ( (1+ ( (0.01987454095662866+ ( ( ( (sub2+ (input_1_10_0*0.01))- ( (0.001*sub2)*0.10000000000000009))+ (input_1_11_0*0.01))- ( (0.001* ( (sub2+ (input_1_10_0*0.01))- ( (0.001*sub2)*0.10000000000000009)))*0.09999999999999987)))*0.09999999999999987))+ (input_1_11_1*0.2)))")
    mul21 = evaluate("( ( (mul20* ( (1+ ( (0.01988701752943629+sub3)*0.10000000000000009))+ (input_1_12_1*0.2)))* ( (1+ ( (0.019900490208159222+ ( (sub3+ (input_1_13_0*0.01))- ( (0.001*sub3)*0.09999999999999987)))*0.09999999999999987))+ (input_1_13_1*0.2)))* ( (1+ ( (0.019914958693741127+ ( ( ( (sub3+ (input_1_13_0*0.01))- ( (0.001*sub3)*0.09999999999999987))+ (input_1_14_0*0.01))- ( (0.001* ( (sub3+ (input_1_13_0*0.01))- ( (0.001*sub3)*0.09999999999999987)))*0.10000000000000009)))*0.10000000000000009))+ (input_1_14_1*0.2)))")
    mul22 = evaluate("( ( (mul21* ( (1+ ( (0.019930422687195398+sub4)*0.10000000000000009))+ (input_1_15_1*0.2)))* ( (1+ ( (0.01994688188960527+ ( (sub4+ (input_1_16_0*0.01))- ( (0.001*sub4)*0.09999999999999987)))*0.09999999999999987))+ (input_1_16_1*0.2)))* ( (1+ ( (0.01996433600212367+ ( ( ( (sub4+ (input_1_16_0*0.01))- ( (0.001*sub4)*0.09999999999999987))+ (input_1_17_0*0.01))- ( (0.001* ( (sub4+ (input_1_16_0*0.01))- ( (0.001*sub4)*0.09999999999999987)))*0.10000000000000009)))*0.10000000000000009))+ (input_1_17_1*0.2)))")
    mul23 = evaluate("( ( (mul22* ( (1+ ( (0.01998278472597332+sub5)*0.09999999999999987))+ (input_1_18_1*0.2)))* ( (1+ ( (0.020002227762446635+ ( (sub5+ (input_1_19_0*0.01))- ( (0.001*sub5)*0.10000000000000009)))*0.10000000000000009))+ (input_1_19_1*0.2)))* ( (1+ ( (0.0200226648129058+ ( ( ( (sub5+ (input_1_19_0*0.01))- ( (0.001*sub5)*0.10000000000000009))+ (input_1_20_0*0.01))- ( (0.001* ( (sub5+ (input_1_19_0*0.01))- ( (0.001*sub5)*0.10000000000000009)))*0.10000000000000009)))*0.10000000000000009))+ (input_1_20_1*0.2)))")
    mul24 = evaluate("( ( (mul23* ( (1+ ( (0.020044095578782617+sub6)*0.10000000000000009))+ (input_1_21_1*0.2)))* ( (1+ ( (0.020066519761578673+ ( (sub6+ (input_1_22_0*0.01))- ( (0.001*sub6)*0.09999999999999964)))*0.09999999999999964))+ (input_1_22_1*0.2)))* ( (1+ ( (0.020089937062865132+ ( ( ( (sub6+ (input_1_22_0*0.01))- ( (0.001*sub6)*0.09999999999999964))+ (input_1_23_0*0.01))- ( (0.001* ( (sub6+ (input_1_22_0*0.01))- ( (0.001*sub6)*0.09999999999999964)))*0.10000000000000009)))*0.10000000000000009))+ (input_1_23_1*0.2)))")
    mul25 = evaluate("( ( (mul24* ( (1+ ( (0.02011434718428291+sub7)*0.10000000000000009))+ (input_1_24_1*0.2)))* ( (1+ ( (0.020139749827542446+ ( (sub7+ (input_1_25_0*0.01))- ( (0.001*sub7)*0.10000000000000009)))*0.10000000000000009))+ (input_1_25_1*0.2)))* ( (1+ ( (0.02016614469442393+ ( ( ( (sub7+ (input_1_25_0*0.01))- ( (0.001*sub7)*0.10000000000000009))+ (input_1_26_0*0.01))- ( (0.001* ( (sub7+ (input_1_25_0*0.01))- ( (0.001*sub7)*0.10000000000000009)))*0.10000000000000009)))*0.10000000000000009))+ (input_1_26_1*0.2)))")
    mul26 = evaluate("( ( (mul25* ( (1+ ( (0.020193531486777085+sub8)*0.09999999999999964))+ (input_1_27_1*0.2)))* ( (1+ ( (0.020221909906521236+ ( (sub8+ (input_1_28_0*0.01))- ( (0.001*sub8)*0.10000000000000009)))*0.10000000000000009))+ (input_1_28_1*0.2)))* ( (1+ ( (0.020251279655645275+ ( ( ( (sub8+ (input_1_28_0*0.01))- ( (0.001*sub8)*0.10000000000000009))+ (input_1_29_0*0.01))- ( (0.001* ( (sub8+ (input_1_28_0*0.01))- ( (0.001*sub8)*0.10000000000000009)))*0.10000000000000009)))*0.10000000000000009))+ (input_1_29_1*0.2)))")
    mul27 = evaluate("( ( (mul26* ( (1+ ( (0.02028164043620774+sub9)*0.10000000000000009))+ (input_1_30_1*0.2)))* ( (1+ ( (0.020312991950336673+ ( (sub9+ (input_1_31_0*0.01))- ( (0.001*sub9)*0.10000000000000009)))*0.10000000000000009))+ (input_1_31_1*0.2)))* ( (1+ ( (0.020345333900229575+ ( ( ( (sub9+ (input_1_31_0*0.01))- ( (0.001*sub9)*0.10000000000000009))+ (input_1_32_0*0.01))- ( (0.001* ( (sub9+ (input_1_31_0*0.01))- ( (0.001*sub9)*0.10000000000000009)))*0.09999999999999964)))*0.09999999999999964))+ (input_1_32_1*0.2)))")
    mul28 = evaluate("( ( (mul27* ( (1+ ( (0.020378665988153574+sub10)*0.10000000000000009))+ (input_1_33_1*0.2)))* ( (1+ ( (0.020412987916445312+ ( (sub10+ (input_1_34_0*0.01))- ( (0.001*sub10)*0.10000000000000009)))*0.10000000000000009))+ (input_1_34_1*0.2)))* ( (1+ ( (0.02044829938751084+ ( ( ( (sub10+ (input_1_34_0*0.01))- ( (0.001*sub10)*0.10000000000000009))+ (input_1_35_0*0.01))- ( (0.001* ( (sub10+ (input_1_34_0*0.01))- ( (0.001*sub10)*0.10000000000000009)))*0.10000000000000009)))*0.10000000000000009))+ (input_1_35_1*0.2)))")
    mul29 = evaluate("( ( (mul28* ( (1+ ( (0.020484600103825704+sub11)*0.10000000000000009))+ (input_1_36_1*0.2)))* ( (1+ ( (0.020521889767934957+ ( (sub11+ (input_1_37_0*0.01))- ( (0.001*sub11)*0.09999999999999964)))*0.09999999999999964))+ (input_1_37_1*0.2)))* ( (1+ ( (0.020560168082453117+ ( ( ( (sub11+ (input_1_37_0*0.01))- ( (0.001*sub11)*0.09999999999999964))+ (input_1_38_0*0.01))- ( (0.001* ( (sub11+ (input_1_37_0*0.01))- ( (0.001*sub11)*0.09999999999999964)))*0.10000000000000009)))*0.10000000000000009))+ (input_1_38_1*0.2)))")
    mul30 = evaluate("( ( (mul29* ( (1+ ( (0.020599434750064056+sub12)*0.10000000000000009))+ (input_1_39_1*0.2)))* ( (1+ ( (0.020639689473521117+ ( (sub12+ (input_1_40_0*0.01))- ( (0.001*sub12)*0.09999999999999964)))*0.09999999999999964))+ (input_1_40_1*0.2)))* ( (1+ ( (0.02068093195564701+ ( ( ( (sub12+ (input_1_40_0*0.01))- ( (0.001*sub12)*0.09999999999999964))+ (input_1_41_0*0.01))- ( (0.001* ( (sub12+ (input_1_40_0*0.01))- ( (0.001*sub12)*0.09999999999999964)))*0.10000000000000053)))*0.10000000000000053))+ (input_1_41_1*0.2)))")
    mul31 = evaluate("( ( (mul30* ( (1+ ( (0.02072316189933383+sub13)*0.09999999999999964))+ (input_1_42_1*0.2)))* ( (1+ ( (0.02076637900754313+ ( (sub13+ (input_1_43_0*0.01))- ( (0.001*sub13)*0.10000000000000053)))*0.10000000000000053))+ (input_1_43_1*0.2)))* ( (1+ ( (0.020810582983305747+ ( ( ( (sub13+ (input_1_43_0*0.01))- ( (0.001*sub13)*0.10000000000000053))+ (input_1_44_0*0.01))- ( (0.001* ( (sub13+ (input_1_43_0*0.01))- ( (0.001*sub13)*0.10000000000000053)))*0.09999999999999964)))*0.09999999999999964))+ (input_1_44_1*0.2)))")
    mul32 = evaluate("( ( (mul31* ( (1+ ( (0.020855773529721826+sub14)*0.09999999999999964))+ (input_1_45_1*0.2)))* ( (1+ ( (0.020901950349960913+ ( (sub14+ (input_1_46_0*0.01))- ( (0.001*sub14)*0.10000000000000053)))*0.10000000000000053))+ (input_1_46_1*0.2)))* ( (1+ ( (0.020949113147261875+ ( ( ( (sub14+ (input_1_46_0*0.01))- ( (0.001*sub14)*0.10000000000000053))+ (input_1_47_0*0.01))- ( (0.001* ( (sub14+ (input_1_46_0*0.01))- ( (0.001*sub14)*0.10000000000000053)))*0.09999999999999964)))*0.09999999999999964))+ (input_1_47_1*0.2)))")
    maximum33 = np.maximum(0,evaluate("(((mul32* ( (1+ ( (0.020997261624932803+sub15)*0.10000000000000053))+ (input_1_48_1*0.2)))* ( (1+ ( (0.021046395486351097+ ( (sub15+ (input_1_49_0*0.01))- ( (0.001*sub15)*0.09999999999999964)))*0.09999999999999964))+ (input_1_49_1*0.2)))-100)"))
    return maximum33

# %%
# %%timeit
cal(np.random.normal(0,1,(100, 1000000)))
# Out:
# 3.45 s ± 31.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
ne.test()
# Out:
# ..............
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Numexpr version:   2.6.4
# NumPy version:     1.14.0
# Python version:    3.6.3 | packaged by conda-forge | (default, Dec  9 2017, 16:18:26)
# [GCC 4.8.2 20140120 (Red Hat 4.8.2-15)]
# Platform:          linux-x86_64
# AMD/Intel CPU?     True
# VML available?     False
# Number of threads used by default: 4 (out of 4 detected cores)
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# ...

# %%
ne.set_num_threads(4)
# Out:
# 2
